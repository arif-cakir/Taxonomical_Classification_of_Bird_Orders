# %% [markdown]
# # TAXONOMICAL CLASSIFICATION OF BIRD ORDERS
# Student Name: Arif Çakır
#
# E-mail: cakirar19@itu.edu.tr
#
# Student Number: 090190355

# %% [markdown]
# ## DATASET AND EXPLANATION
#
# ### Dataset
# In this project, a dataset named [Brain size and life history variables in birds](https://datadryad.org/stash/dataset/doi:10.5061/dryad.sqv9s4n27) from [datadryad.org](datadryad.org) is going to be used as the subject data set. The dataset is merged by Jiménez-Ortega et al. from various studies and datasets due to the incompleteness of those datasets.

# %%
import pandas as pd

df = pd.read_excel("https://datadryad.org/stash/downloads/file_stream/401942").dropna()
df
# Out:
#     class            order          family         genus            spp  \
# 1    Aves  Accipitriformes    Accipitridae     Accipiter       cooperii
# 2    Aves  Accipitriformes    Accipitridae     Accipiter       gentilis
# 3    Aves  Accipitriformes    Accipitridae     Accipiter       striatus
# 5    Aves    Passeriformes  Acrocephalidae  Acrocephalus   arundinaceus
# 6    Aves    Passeriformes  Acrocephalidae  Acrocephalus  schoenobaenus
# ..    ...              ...             ...           ...            ...
# 615  Aves    Passeriformes     Emberizidae   Zonotrichia     albicollis
# 616  Aves    Passeriformes     Emberizidae   Zonotrichia     leucophrys
# 617  Aves    Passeriformes        Turdidae      Zoothera         naevia
# 618  Aves    Passeriformes    Zosteropidae     Zosterops      japonicus
# 619  Aves    Passeriformes    Zosteropidae     Zosterops      lateralis
#
#                         species  clutch.size  max.longevity  incubation  \
# ...

# %% [markdown]
# ### Dataset Explanation
# The dataset contains of 18 columns. first 6 are taxonomical properties of the birds:
# - "class": Taxonomic class of the bird (which is same for all birds).
# - "order": Taxonomic order of the bird.
# - "family": Taxonomic family of the bird.
# - "genus": Taxonomic genus of the bird.
# - "spp": Taxonomic species of the bird.
# - "species": Subject's taxonomical name, which is "genus"_"spp".
#
# After that, columns 6-13 are for estimated values of physiological and ethological features of the birds:
# - "clutch.size": Species' estimated size of clutch.
# - "max.longevity": Maximum age of species.
# - "incubation": Species' estimated duration of incubation
# - "dev.mode": Development model of species. "A" for altricial, "SA" for semialtricial, "P" for precocial and "SP" for semiprecocial.
# - "fledling.age": Estimated age of fledging.
# - "brain.mass": Estimated brain mass of species.
# - "egg.mass": Species' estimated egg mass.
# - "body.mass": Species' estimated body mass
# - "specimen.origin": Origin of species; captivity and wild.
#
# Finally, last three columns are for reference issues and not significant for the project:
# - "qc": Quality control acceptability. Only acceptable ones will be taken for the project.
# - "sample.size": size of the sample; small, medium, large.
# - "references": Used references from website.

# %% [markdown]
# ## Purpose of the Project
# There are two objectives in this project: Firstly, it is aimed to taxonomically classify bird species in respect of their physiological and ethological characteristics and secondly, creating new labels as close as possible to taxonomic labels with the help of clustering algorithms. In biological taxonomy, organisms are classified by their basis of shared physical likeness with the help of eight hierarchical categories which are: domain, kingdom, phylum, class, order, family, genus, and species. This hierarchy goes from general to specific and all classes are an inclusive group of higher ranks. Moreover, it is planned to verify that physiological and ethological characteristics like egg size, incubation duration, development model, etc. can be used as an indicator of taxonomic classification in this project. Aves class contains 27 orders, 98 families, and 338 genera; due to the higher number of families and genera, orders are going to be used in this project.
#
# In summary, the hypothesis of this project is "Bird species can be distinguished and predicted with the help of their physiological and ethological characteristics".

# %% [markdown]
# ## Methods
# Due to the fact that one of the objectives is classifying and other one is clustering, both supervised and unsupervised algorithms are going to be used. Firstly, Support Vector Machines will be used to classify birds because of the existance of more that two distinct outputs. Secondly, due to the bottom-up approach of the second objective, agglomerative hierarchial clustering is going to be used. Output of hierarchial clustering is predicted to be close to orders of birds because of the number. Furthermore, additional models will be constructed by DBSCAN, decision tree and k-means algorithms for comparison with the first models. Finally, the clusters will be compared to dataset and named.
#
# ### Calendar
#
# - Week 1: Data preparation and pre-analysis
# - Week 2: SVM and Hierarchial Clustering
# - Week 3: K-Means Decision Tree and DBSCAN
# - Week 4: Summary of the results

# %% [markdown]
# # 15.11.22

# %% [markdown]
# ## Atabey's notes
#
# ### Round 1
#
# I very much liked the dataset and your detailed explanations. I also liked your questions. However, your methods section requires some work. You need to explain how you are going to classify/cluster the data: which algorithms are available? Which ones are you going to choose? Why? Clearly state your hypothesis (bird species can be distinguished using the features provided within the dataset) and then explain how the ML algorithm you chose are going to test the hypothesis. What is the test you are going to use to decide if the data/experiment is consistent or contradictory with the hypothesis.
#
# Also, you must provide a calendar (what are you going to do and when).
#
# ### Round 2
#
# Looks good. Go ahead.
